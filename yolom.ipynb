# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanrai14022008/ml-projects/blob/main/yolom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 50.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=YOLO('yolov8n.pt')

# %%
results=model('/content/sample_data/1.jpg')
# Out:
# image 1/1 /content/sample_data/1.jpg: 480x640 1 person, 1 dog, 364.4ms
# Speed: 15.6ms preprocess, 364.4ms inference, 39.4ms postprocess per image at shape (1, 3, 480, 640)

# %%
results[0].save('aryan.jpg')
# Out:
# 'aryan.jpg'
